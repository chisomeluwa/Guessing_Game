# %%
# importing the random module
import random
#Welcome users to play the game
print("Hey buddie, Welcome to the START-NG Guessing Game!")
def guessGame():
    # Set up main variables
    difficulty_ranges = {'e': 10, 'm': 20, 'h': 50}   #Use dictionary to set up game levels
    while True:
        try:
            magic_number= input("Type E, M or H for easy (1-10), medium (1-20), hard (1-50) : ")
            break
        except KeyError:
            print("Incorrect input! Choose again...")  # Encourage user to input correctly
            break
        continue
def easy_level_game():
    guess_count = 0
    try_limit = 6
    difficulty_ranges = {'e': 10, 'm': 20, 'h': 50}
    level = input(
            "Type E, M or H for easy (1-10), medium (1-20), or hard (1-50) number range:\n").lower()
    LEVEL= level
    magic_number = random.randint(1, difficulty_ranges[LEVEL])
    while guess_count < try_limit:
        while True:
            try:
                player_input = int(input("Guess the secret number, it is between 1 - 10: "))
                guess_count += 1
                print(f'That was wrong! you have {try_limit-guess_count} attempts left')
            except ValueError:
                print("Incorrect input! Choose a number")
                continue
            break
            if player_input<1 or player_input>10:
                print("Your input was incorrect, Enter a value between 1 and 10 \n")
                continue
            elif player_input == magic_number:
                print("You got it right!")
                break
            if player_input != magic_number:
                (f'That was wrong! you have {try_limit-guess_count} attempts left')
                continue
            else:
                print("Game Over!")
                break
def medium_level_game():
    guess_count = 0
    try_limit = 4
    difficulty_ranges = {'e': 10, 'm': 20, 'h': 50}
    level = input(
            "Type E, M or H for easy (1-10), medium (1-20), or hard (1-50) number range:\n").lower()
    LEVEL= level
    magic_number = random.randint(1, difficulty_ranges[LEVEL])
    while guess_count < try_limit:
        while True:
            try:
                player_input = int(input("Guess the secret number, it is between 1 - 20: "))
                guess_count += 1
                print(f'That was wrong! you have {try_limit-guess_count} attempts left')
            except ValueError:
                print("Incorrect input! Choose a number")
                continue
            break
            if player_input<1 or player_input>20:
                print("Your input was incorrect, Enter a value between 1 and 20 \n")
                continue
            elif player_input == magic_number:
                print("You got it right!")
                break
            if player_input != magic_number:
                (f'That was wrong! you have {try_limit-guess_count} attempts left')
                continue
            else:
                print("Game Over!")
                break
def hard_level_game():
    guess_count = 0
    try_limit = 3
    difficulty_ranges = {'e': 10, 'm': 20, 'h': 50}
    level = input(
            "Type E, M or H for easy (1-10), medium (1-20), or hard (1-50) number range:\n").lower()
    LEVEL= level
    magic_number = random.randint(1, difficulty_ranges[LEVEL])
    while guess_count < try_limit:
        while True:
            try:
                player_input = int(input("Guess the secret number, it is between 1 - 50: "))
                guess_count += 1
                print(f'That was wrong! you have {try_limit-guess_count} attempts left')
            except ValueError:
                print("Incorrect input! Choose a number")
                continue
            break
            if player_input<1 or player_input>50:
                print("Your input was incorrect, Enter a value between 1 and 50 \n")
                continue
            elif player_input == magic_number:
                print("You got it right!")
                break
            if player_input != magic_number:
                (f'That was wrong! you have {try_limit-guess_count} attempts left')
                continue
            else:
                print("Game Over!")

def play_the_game():
    play = input("Enter game level e, m, or h for easy, medium, hard:")
    if play == 'e':
        easy_level_game()
    elif play == 'm':
        medium_level_game()
    elif play == 'h':
        hard_level_game()
play_the_game()
# Out:
# Hey buddie, Welcome to the START-NG Guessing Game!
